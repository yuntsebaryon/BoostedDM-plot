# %%
import ROOT
ROOT.gStyle.SetOptStat(0)
f = ROOT.TFile("/Users/yuntse/Work/pheno/BoostedDM/gallery/srcs/MCDistributions.root", "READ")
# Out:
# Welcome to JupyROOT 6.12/04

# %%
t = f.Get("MCParticles")

# %%
h = ROOT.TH1F("nProtonGen", "Number of Protons Generated", 10, 0, 10)

# %%
for i in t:
    h.Fill(i.nProtonsGen)

# %%
c = ROOT.TCanvas("nProtonsGen", "Number of Protons Generated", 800, 600)
h.Draw()
c.Draw()
