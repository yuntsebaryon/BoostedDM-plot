# %%
import ROOT
import math
ROOT.gStyle.SetOptStat(0)
f = ROOT.TFile("/Users/yuntse/Data/pheno/BoostedDM/dune_v07_06_01/atmos/ana/BkgdSmearedMCParticles.root", "READ")
# Out:
# Welcome to JupyROOT 6.12/06

# %%
t = f.Get("MCParticles")

# %%
hnProtons = ROOT.TH1F("nProtons", "Number of Protons", 10, 0, 10)
hnParticles = ROOT.TH1F("nParticles", "Number of Particles", 10, 0, 10)
hLeadingProtonPx = ROOT.TH1D("LeadingProtonPx", "Leading Proton Px", 100, -0.5, 0.5)
hLeadingParticleCosAngle = ROOT.TH1D("LeadingParticleCosAngle", "Leading Particle Cos(Angle)", 50, -1., 1. )
hLeadingParticleNoNCosAngle = ROOT.TH1D("LeadingParticeNoNCosAngle", "Leading Particle (without neutrons) Cos(Angle)", 50, -1., 1. )
hVisibleCosAngle = ROOT.TH1D("VisibleCosAngle", "Visible Cos(Angle)", 50, -1., 1. )
hVisibleNoNCosAngle = ROOT.TH1D("VisibleNoNCosAngle", "Visible (without neutrons) Cos(Angle)", 50, -1., 1. )
hInNuP = ROOT.TH1D("InNuP", "Incoming Neutrino Momentum", 50, 0., 10. )
hOutNuP = ROOT.TH1D("OutNuP", "Outgoing Neutrino Momentum", 50, 0., 10. )
hInNuCosAngle = ROOT.TH1D("InNuAngle", "Incoming Neutrino Cos(Angle)", 50, -1., 1. )
hOutNuCosAngle = ROOT.TH1D("OutNuAngle", "Outgoing Neutrino Cos(Angle)", 50, -1., 1. )
hSmearedVisibleCosAngle = ROOT.TH1D("SmearedVisibleCosAngle", "Visible Cos(Angle) after Smearing", 50, -1., 1. )
hSmearedVisibleNoNCosAngle = ROOT.TH1D("SmearedVisibleNoNCosAngle", "Visible (without neutrons) Cos(Angle) after Smearing", 50, -1., 1. )
hSmearedRecontableCosAngle = ROOT.TH1D("SmearedReconstructableCosAngle", "Reconstructable Cos(Angle) after smearing", 50, -1., 1.)
hSmearedRecontableNoNCosAngle = ROOT.TH1D("SmearedReconstructableNoNCosAngle", "Reconstructable (without neutrons) Cos(Angle) after smearing", 50, -1., 1.)
hLeadingSmearedCosAngle = ROOT.TH1D("LeadingSmeared", "Cos(Angle) of the leading particle after smearing", 50, -1., 1.)
hLeadingSmearedNoNCosAngle = ROOT.TH1D("LeadingSmearedNoN", "Cos(Angle) of the leading particle (without neutron) after smearing", 50, -1., 1. )
hLeadingRecontableCosAngle = ROOT.TH1D("LeadingRecontructableCosAngle", "Cos(Angle) of the leading recontructable particle after smearing", 50, -1., 1. )
hLeadingRecontableNoNCosAngle = ROOT.TH1D("LeadingReconstructableNoNCosAngle", "Cos(Angle) of the leading reconstructable particle (without neutrons) after smearing", 50, -1., 1. )

# %%
nLeadingParticleCosAngle = 0
nLeadingParticleNoNCosAngle = 0
nVisibleCosAngle = 0
nVisibleNoNCosAngle = 0
nSmearedVisibleCosAngle = 0
nSmearedVisibleNoNCosAngle = 0
nRecontableCosAngle = 0
nRecontableNoNCosAngle = 0
nLeadingSmearedCosAngle = 0
nLeadingSmearedNoNCosAngle = 0
nLeadingRecontableCosAngle = 0
nLeadingRecontableNoNCosAngle = 0

for i in t:
    hnProtons.Fill(i.nProtons)
    if len(i.ProtonPx) > 0:
        hLeadingProtonPx.Fill(i.ProtonPx[0])
    LeadingParticleCosAngle = math.cos(i.LeadingParticleAngle[0])
    hLeadingParticleCosAngle.Fill(LeadingParticleCosAngle)
    if LeadingParticleCosAngle > 0.7:
        nLeadingParticleCosAngle += 1
    LeadingParticleNoNCosAngle = math.cos(i.LeadingParticleNoNAngle[0])
    hLeadingParticleNoNCosAngle.Fill(LeadingParticleNoNCosAngle)
    if LeadingParticleNoNCosAngle > 0.7:
        nLeadingParticleNoNCosAngle += 1
    VisibleCosAngle = math.cos(i.VisibleAngle[0])
    hVisibleCosAngle.Fill(VisibleCosAngle)
    if VisibleCosAngle > 0.7:
        nVisibleCosAngle += 1
    VisibleNoNCosAngle = math.cos(i.VisibleNoNAngle[0])
    hVisibleNoNCosAngle.Fill(VisibleNoNCosAngle)
    if VisibleNoNCosAngle > 0.7:
        nVisibleNoNCosAngle += 1
    hInNuP.Fill(i.InNuP[0])
    hOutNuP.Fill(i.OutNuP[0])
    InNuCosAngle = math.cos(i.InNuAngle[0])
    hInNuCosAngle.Fill( InNuCosAngle )
    OutNuCosAngle = math.cos(i.OutNuAngle[0])
    hOutNuCosAngle.Fill(OutNuCosAngle)
    SmearedVisibleCosAngle = math.cos(i.SmearedVisibleAngle[0])
    hSmearedVisibleCosAngle.Fill(SmearedVisibleCosAngle)
    if SmearedVisibleCosAngle > 0.7:
        nSmearedVisibleCosAngle += 1
    SmearedVisibleNoNCosAngle = math.cos(i.SmearedVisibleNonAngle[0])
    hSmearedVisibleNoNCosAngle.Fill(SmearedVisibleNoNCosAngle)
    if SmearedVisibleNoNCosAngle > 0.7:
        nSmearedVisibleNoNCosAngle += 1
    SmearedRecontableCosAngle = math.cos(i.SmearedReconstructableAngle[0])
    hSmearedRecontableCosAngle.Fill(SmearedRecontableCosAngle)
    if SmearedRecontableCosAngle > 0.7:
        nRecontableCosAngle += 1
    SmearedRecontableNoNCosAngle = math.cos(i.SmearedReconstructableNoNAngle[0])
    hSmearedRecontableNoNCosAngle.Fill(SmearedRecontableNoNCosAngle)
    if SmearedRecontableNoNCosAngle > 0.7:
        nRecontableNoNCosAngle += 1
    LeadingSmearedCosAngle = math.cos(i.LeadingSmearedAngle[0])
    hLeadingSmearedCosAngle.Fill(LeadingSmearedCosAngle)
    if LeadingSmearedCosAngle > 0.7:
        nLeadingSmearedCosAngle += 1
    LeadingSmearedNoNCosAngle = math.cos(i.LeadingSmearedNoNAngle[0])
    hLeadingSmearedNoNCosAngle.Fill(LeadingSmearedNoNCosAngle)
    if LeadingSmearedNoNCosAngle > 0.7:
        nLeadingSmearedNoNCosAngle += 1
    LeadingRecontableCosAngle = math.cos(i.LeadingSmearedReconstructableAngle[0])
    hLeadingRecontableCosAngle.Fill(LeadingRecontableCosAngle)
    if LeadingRecontableCosAngle > 0.7:
        nLeadingRecontableCosAngle += 1
    LeadingRecontableNoNCosAngle = math.cos(i.LeadingSmearedReconstructableNoNAngle[0])
    hLeadingRecontableNoNCosAngle.Fill(LeadingRecontableNoNCosAngle)
    if LeadingRecontableNoNCosAngle > 0.7:
        nLeadingRecontableNoNCosAngle += 1

# %%
cnProtons = ROOT.TCanvas("nProtons", "Number of Protons Generated", 800, 600)
hnProtons.Draw()
cnProtons.Draw()

# %%
cLeadingParticleCosAngle = ROOT.TCanvas("LeadingParticleCosAngle", "Leading Particle Cos(Angle)", 800, 600)
cLeadingParticleCosAngle.SetBottomMargin(0.15)
hLeadingParticleCosAngle.SetLineColor(593)
hLeadingParticleCosAngle.SetLineWidth(3)
hLeadingParticleCosAngle.SetTitle("")
hLeadingParticleCosAngle.GetXaxis().SetTitle("cos(#theta)")
hLeadingParticleCosAngle.GetXaxis().SetTitleSize(0.07)
hLeadingParticleCosAngle.GetXaxis().SetLabelSize(0.06)
hLeadingParticleCosAngle.GetYaxis().SetLabelSize(0.06)
hLeadingParticleCosAngle.GetYaxis().SetRangeUser(0, 240)
hLeadingParticleCosAngle.Draw()
hLeadingParticleNoNCosAngle.SetLineColor(906)
hLeadingParticleNoNCosAngle.SetLineWidth(3)
hLeadingParticleNoNCosAngle.Draw("same")
lLeadingParticleCosAngle = ROOT.TLegend( 0.15, 0.2, 0.55, 0.4 )
lLeadingParticleCosAngle.SetBorderSize(0)
lLeadingParticleCosAngle.SetFillStyle(0)
lLeadingParticleCosAngle.AddEntry( hLeadingParticleCosAngle, "With Neutrons")
lLeadingParticleCosAngle.AddEntry( hLeadingParticleNoNCosAngle, "No Neutron")
lLeadingParticleCosAngle.Draw()
cLeadingParticleCosAngle.Draw()
cLeadingParticleCosAngle.SaveAs('LeadingParticleCosAngle.png')
# Out:
# Info in <TCanvas::Print>: png file LeadingParticleCosAngle.png has been created

# %%
cVisibleCosAngle = ROOT.TCanvas("VisibleCosAngle", "Leading Particle Cos(Angle)", 800, 600)
cVisibleCosAngle.SetBottomMargin(0.15)
hVisibleCosAngle.SetLineColor(593)
hVisibleCosAngle.SetLineWidth(3)
hVisibleCosAngle.SetTitle("")
hVisibleCosAngle.GetXaxis().SetTitle("cos(#theta)")
hVisibleCosAngle.GetXaxis().SetTitleSize(0.07)
hVisibleCosAngle.GetXaxis().SetLabelSize(0.06)
hVisibleCosAngle.GetYaxis().SetLabelSize(0.06)
hVisibleCosAngle.GetYaxis().SetRangeUser(0, 240)
hVisibleCosAngle.Draw()
hVisibleNoNCosAngle.SetLineColor(906)
hVisibleNoNCosAngle.SetLineWidth(3)
hVisibleNoNCosAngle.Draw("same")
lVisibleCosAngle = ROOT.TLegend( 0.15, 0.2, 0.55, 0.4 )
lVisibleCosAngle.SetBorderSize(0)
lVisibleCosAngle.SetFillStyle(0)
lVisibleCosAngle.AddEntry( hVisibleCosAngle, "With Neutrons")
lVisibleCosAngle.AddEntry( hVisibleNoNCosAngle, "No Neutron")
lVisibleCosAngle.Draw()
cVisibleCosAngle.Draw()
cVisibleCosAngle.SaveAs("VisibleCosAngle.png")
# Out:
# Info in <TCanvas::Print>: png file VisibleCosAngle.png has been created

# %%
print 'n( LeadingParticleCos(Angle) > 0.7 ): %d' % nLeadingParticleCosAngle
print 'n( LeadingParticleNoNCos(Angle) > 0.7 ): %d' % nLeadingParticleNoNCosAngle
print 'n( VisibleCos(Angle) > 0.7 ): %d' % nVisibleCosAngle
print 'n( VisibleNoNCos(Angle) > 0.7 ): %d' % nVisibleNoNCosAngle
print 'n( SmearedVisibleCos(Angle) > 0.7 ): %d' % nSmearedVisibleCosAngle
print 'n( SmearedVisibleNoNCos(Angle) > 0.7 ): %d' % nSmearedVisibleNoNCosAngle
print 'n( SmearedReconstructableCos(Angle) > 0.7 ): %d' % nRecontableCosAngle
print 'n( SmearedReconstructableNoNCos(Angle) > 0.7 ): %d' % nRecontableNoNCosAngle
print 'n( LeadingSmearedCos(Angle) > 0.7 ): %d' % nLeadingSmearedCosAngle
print 'n( LeadingSmearedNoNCos(Angle) > 0.7 ): %d' % nLeadingSmearedNoNCosAngle
print 'n( LeadingReconstructableCos(Angle) > 0.7 ): %d' % nLeadingRecontableCosAngle
print 'n( LeadingReconstructableNoNCos(Angle) > 0.7 ): %d' % nLeadingRecontableNoNCosAngle
# Out:
# n( LeadingParticleCos(Angle) > 0.7 ): 1379
# n( LeadingParticleNoNCos(Angle) > 0.7 ): 1010
# n( VisibleCos(Angle) > 0.7 ): 1407
# n( VisibleNoNCos(Angle) > 0.7 ): 1009
# n( SmearedVisibleCos(Angle) > 0.7 ): 1983
# n( SmearedVisibleNoNCos(Angle) > 0.7 ): 1537
# n( SmearedReconstructableCos(Angle) > 0.7 ): 1277
# n( SmearedReconstructableNoNCos(Angle) > 0.7 ): 978
# n( LeadingSmearedCos(Angle) > 0.7 ): 1964
# n( LeadingSmearedNoNCos(Angle) > 0.7 ): 1522
# n( LeadingReconstructableCos(Angle) > 0.7 ): 1182
# n( LeadingReconstructableNoNCos(Angle) > 0.7 ): 1526

# %%
cNuP = ROOT.TCanvas("NuP", "Neutrino Momentum", 800, 600)
cNuP.SetBottomMargin(0.15)
hInNuP.SetLineColor(593)
hInNuP.SetLineWidth(3)
hInNuP.SetTitle("")
hInNuP.GetXaxis().SetTitle("Momentum [GeV]")
hInNuP.GetXaxis().SetTitleSize(0.07)
hInNuP.GetXaxis().SetLabelSize(0.06)
hInNuP.GetYaxis().SetLabelSize(0.05)
hInNuP.GetYaxis().SetRangeUser(0, 4000)
hInNuP.Draw()
hOutNuP.SetLineColor(906)
hOutNuP.SetLineWidth(3)
hOutNuP.Draw("same")
lNuP = ROOT.TLegend( 0.45, 0.6, 0.85, 0.8 )
lNuP.SetBorderSize(0)
lNuP.SetFillStyle(0)
lNuP.AddEntry( hInNuP, "Incoming Nu")
lNuP.AddEntry( hOutNuP, "Outgoing Nu")
lNuP.Draw()
cNuP.Draw()
cNuP.SaveAs("NuP.png")
# Out:
# Info in <TCanvas::Print>: png file NuP.png has been created

# %%
cNuCosAngle = ROOT.TCanvas("NuCosAngle", "Neutrino Cos(Angle)", 800, 600)
cNuCosAngle.SetBottomMargin(0.15)
hOutNuCosAngle.SetLineColor(906)
hOutNuCosAngle.SetLineWidth(3)
hOutNuCosAngle.SetTitle("")
hOutNuCosAngle.GetXaxis().SetTitle("cos(#theta)")
hOutNuCosAngle.GetXaxis().SetTitleSize(0.07)
hOutNuCosAngle.GetXaxis().SetLabelSize(0.06)
hOutNuCosAngle.GetYaxis().SetLabelSize(0.06)
hOutNuCosAngle.GetYaxis().SetRangeUser(100, 340)
hOutNuCosAngle.Draw()
hInNuCosAngle.SetLineColor(593)
hInNuCosAngle.SetLineWidth(3)
hInNuCosAngle.Draw("same")
lNuCosAngle = ROOT.TLegend( 0.15, 0.2, 0.55, 0.4 )
lNuCosAngle.SetBorderSize(0)
lNuCosAngle.SetFillStyle(0)
lNuCosAngle.AddEntry( hInNuCosAngle, "Incoming Nu")
lNuCosAngle.AddEntry( hOutNuCosAngle, "Outgoing Nu")
lNuCosAngle.Draw()
cNuCosAngle.Draw()
cNuCosAngle.SaveAs("NuCosAngle.png")
# Out:
# Info in <TCanvas::Print>: png file NuCosAngle.png has been created

# %%
cLeadingProtonPx = ROOT.TCanvas("LeadingProtonPx", "Leading Proton Px", 800, 600)
hLeadingProtonPx.Draw()
cLeadingProtonPx.Draw()

# %%
cSmearedVisibleCosAngle = ROOT.TCanvas("SmearedVisibleCosAngle", "Cos(Angle) of the vector sum of all the smeared visible particles", 800, 600)
cSmearedVisibleCosAngle.SetBottomMargin(0.15)
hSmearedVisibleCosAngle.SetLineColor(593)
hSmearedVisibleCosAngle.SetLineWidth(3)
hSmearedVisibleCosAngle.SetTitle("")
hSmearedVisibleCosAngle.GetXaxis().SetTitle("cos(#theta)")
hSmearedVisibleCosAngle.GetXaxis().SetTitleSize(0.07)
hSmearedVisibleCosAngle.GetXaxis().SetLabelSize(0.06)
hSmearedVisibleCosAngle.GetYaxis().SetLabelSize(0.06)
hSmearedVisibleCosAngle.GetYaxis().SetRangeUser(0, 320)
hSmearedVisibleCosAngle.Draw()
hSmearedVisibleNoNCosAngle.SetLineColor(906)
hSmearedVisibleNoNCosAngle.SetLineWidth(3)
hSmearedVisibleNoNCosAngle.Draw("same")
lSmearedVisibleCosAngle = ROOT.TLegend( 0.15, 0.2, 0.55, 0.4 )
lSmearedVisibleCosAngle.SetBorderSize(0)
lSmearedVisibleCosAngle.SetFillStyle(0)
lSmearedVisibleCosAngle.AddEntry( hSmearedVisibleCosAngle, "With Neutrons")
lSmearedVisibleCosAngle.AddEntry( hSmearedVisibleNoNCosAngle, "No Neutron")
lSmearedVisibleCosAngle.Draw()
cSmearedVisibleCosAngle.Draw()
cSmearedVisibleCosAngle.SaveAs("SmearedVisibleCosAngle.png")
# Out:
# Info in <TCanvas::Print>: png file SmearedVisibleCosAngle.png has been created

# %%
cSmearedRecontableCosAngle = ROOT.TCanvas("SmearedReconstructableCosAngle", "Cos(Angle) of the vector sum of all the smeared reconstructable particles", 800, 600)
cSmearedRecontableCosAngle.SetBottomMargin(0.15)
hSmearedRecontableCosAngle.SetLineColor(593)
hSmearedRecontableCosAngle.SetLineWidth(3)
hSmearedRecontableCosAngle.SetTitle("")
hSmearedRecontableCosAngle.GetXaxis().SetTitle("cos(#theta)")
hSmearedRecontableCosAngle.GetXaxis().SetTitleSize(0.07)
hSmearedRecontableCosAngle.GetXaxis().SetLabelSize(0.06)
hSmearedRecontableCosAngle.GetYaxis().SetLabelSize(0.06)
hSmearedRecontableCosAngle.GetYaxis().SetRangeUser(0, 220)
hSmearedRecontableCosAngle.Draw()
hSmearedRecontableNoNCosAngle.SetLineColor(906)
hSmearedRecontableNoNCosAngle.SetLineWidth(3)
hSmearedRecontableNoNCosAngle.Draw("same")
lSmearedRecontableCosAngle = ROOT.TLegend( 0.15, 0.2, 0.55, 0.4 )
lSmearedRecontableCosAngle.SetBorderSize(0)
lSmearedRecontableCosAngle.SetFillStyle(0)
lSmearedRecontableCosAngle.AddEntry( hSmearedRecontableCosAngle, "With Neutrons")
lSmearedRecontableCosAngle.AddEntry( hSmearedRecontableNoNCosAngle, "No Neutron")
lSmearedRecontableCosAngle.Draw()
cSmearedRecontableCosAngle.Draw()
cSmearedRecontableCosAngle.SaveAs("SmearedReconstructableCosAngle.png")
# Out:
# Info in <TCanvas::Print>: png file SmearedReconstructableCosAngle.png has been created

# %%
cLeadingSmearedCosAngle = ROOT.TCanvas("LeadingSmearedCosAngle", "Cos(Angle) of the leading particle after smearing", 800, 600)
cLeadingSmearedCosAngle.SetBottomMargin(0.15)
hLeadingSmearedCosAngle.SetLineColor(593)
hLeadingSmearedCosAngle.SetLineWidth(3)
hLeadingSmearedCosAngle.SetTitle("")
hLeadingSmearedCosAngle.GetXaxis().SetTitle("cos(#theta)")
hLeadingSmearedCosAngle.GetXaxis().SetTitleSize(0.07)
hLeadingSmearedCosAngle.GetXaxis().SetLabelSize(0.06)
hLeadingSmearedCosAngle.GetYaxis().SetLabelSize(0.06)
hLeadingSmearedCosAngle.GetYaxis().SetRangeUser(0,320)
hLeadingSmearedCosAngle.Draw()
hLeadingSmearedNoNCosAngle.SetLineColor(906)
hLeadingSmearedNoNCosAngle.SetLineWidth(3)
hLeadingSmearedNoNCosAngle.Draw("same")
lLeadingSmearedCosAngle = ROOT.TLegend( 0.15, 0.2, 0.55, 0.4 )
lLeadingSmearedCosAngle.SetBorderSize(0)
lLeadingSmearedCosAngle.SetFillStyle(0)
lLeadingSmearedCosAngle.AddEntry( hLeadingSmearedCosAngle, "With Neutrons")
lLeadingSmearedCosAngle.AddEntry( hLeadingSmearedNoNCosAngle, "No Neutron")
lLeadingSmearedCosAngle.Draw()
cLeadingSmearedCosAngle.Draw()
cLeadingSmearedCosAngle.SaveAs("LeadingSmearedCosAngle.png")
# Out:
# Info in <TCanvas::Print>: png file LeadingSmearedCosAngle.png has been created

# %%
cLeadingRecontableCosAngle = ROOT.TCanvas("LeadingSmearedReconstructableCosAngle", "Cos(Angle) of the leading reconstructable particle after smearing", 800, 600)
cLeadingRecontableCosAngle.SetBottomMargin(0.15)
hLeadingRecontableCosAngle.SetLineColor(593)
hLeadingRecontableCosAngle.SetLineWidth(3)
hLeadingRecontableCosAngle.SetTitle("")
hLeadingRecontableCosAngle.GetXaxis().SetTitle("cos(#theta)")
hLeadingRecontableCosAngle.GetXaxis().SetTitleSize(0.07)
hLeadingRecontableCosAngle.GetXaxis().SetLabelSize(0.06)
hLeadingRecontableCosAngle.GetYaxis().SetLabelSize(0.06)
hLeadingRecontableCosAngle.GetYaxis().SetRangeUser(0, 250)
hLeadingRecontableCosAngle.Draw()
hLeadingRecontableNoNCosAngle.SetLineColor(906)
hLeadingRecontableNoNCosAngle.SetLineWidth(3)
hLeadingRecontableNoNCosAngle.Draw("same")
lLeadingRecontableCosAngle = ROOT.TLegend( 0.15, 0.2, 0.55, 0.4 )
lLeadingRecontableCosAngle.SetBorderSize(0)
lLeadingRecontableCosAngle.SetFillStyle(0)
lLeadingRecontableCosAngle.AddEntry( hLeadingRecontableCosAngle, "With Neutrons")
lLeadingRecontableCosAngle.AddEntry( hLeadingRecontableNoNCosAngle, "No Neutron")
lLeadingRecontableCosAngle.Draw()
cLeadingRecontableCosAngle.Draw()
cLeadingRecontableCosAngle.SaveAs("LeadingSmearedReconstructableCosAngle.png")
# Out:
# Info in <TCanvas::Print>: png file LeadingSmearedReconstructableCosAngle.png has been created
